# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pwd
# Out:
# 'C:\\Users\\yoges\\Downloads\\dt\\sc\\use_cases_EDA-20230726T032827Z-001\\use_cases_EDA\\zomato'

# %%
zomato_real=pd.read_csv("C:\\Users\\yoges\\Downloads\\dt\\sc\\use_cases_EDA-20230726T032827Z-001\\use_cases_EDA\\zomato.csv")

# %%
type(zomato_real)
# Out:
# pandas.core.frame.DataFrame

# %%
zomato_real.shape
# Out:
# (51717, 17)

# %%
zomato_real.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_real.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
zomato_real.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato_real.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
zomato_real.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
zomato1=zomato_real.drop(['url','dish_liked','phone'],axis=1)

# %%
zomato1.shape
# Out:
# (51717, 14)

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1.duplicated().sum()
# Out:
# 43

# %%
51717-43
# Out:
# 51674

# %%
zomato1.drop_duplicates(inplace=True)

# %%
zomato1.shape
# Out:
# (51674, 14)

# %%
zomato1.isnull().sum()
# Out:
# address                           0
# name                              0
# online_order                      0
# book_table                        0
# rate                           7767
# votes                             0
# location                         21
# rest_type                       227
# cuisines                         45
# approx_cost(for two people)     345
# reviews_list                      0
# menu_item                         0
# listed_in(type)                   0
# listed_in(city)                   0
# dtype: int64

# %%
zomato1.dropna(how='any',inplace=True)

# %%
zomato1.shape
# Out:
# (43499, 14)

# %%
zomato1.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'approx_cost(for two people)',
#        'reviews_list', 'menu_item', 'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
zomato1_rename = zomato1.rename(columns={'approx_cost(for two people)':'cost',
                                         'listed_in(type)':'type',
                                  'listed_in(city)':'city'})

# %%
zomato1_rename.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'location', 'rest_type', 'cuisines', 'cost', 'reviews_list',
#        'menu_item', 'type', 'city'],
#       dtype='object')

# %%
zomato1_rename['cost'] = zomato1_rename['cost'].astype(str) #Changing the cost to string

# %%
zomato1_rename['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1,500
# 51715    2,500
# 51716    1,500
# Name: cost, Length: 43499, dtype: object

# %%
zomato1_rename['cost'] = zomato1_rename['cost'].apply(lambda x: x.replace(',','.')) #Using lambda function to replace ',' from cost

# %%
zomato1_rename['cost']
# Out:
# 0          800
# 1          800
# 2          800
# 3          300
# 4          600
#          ...
# 51709      800
# 51711      800
# 51712    1.500
# 51715    2.500
# 51716    1.500
# Name: cost, Length: 43499, dtype: object

# %%
zomato1_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       43499 non-null  object
#  1   name          43499 non-null  object
#  2   online_order  43499 non-null  object
#  3   book_table    43499 non-null  object
#  4   rate          43499 non-null  object
#  5   votes         43499 non-null  int64
#  6   location      43499 non-null  object
#  7   rest_type     43499 non-null  object
#  8   cuisines      43499 non-null  object
#  9   cost          43499 non-null  object
#  10  reviews_list  43499 non-null  object
#  11  menu_item     43499 non-null  object
#  12  type          43499 non-null  object
#  13  city          43499 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 5.0+ MB

# %%
zomato1_rename['cost'] = zomato1_rename['cost'].astype(float) # Changing the cost to Float

# %%
zomato1_rename.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 43499 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       43499 non-null  object
#  1   name          43499 non-null  object
#  2   online_order  43499 non-null  object
#  3   book_table    43499 non-null  object
#  4   rate          43499 non-null  object
#  5   votes         43499 non-null  int64
#  6   location      43499 non-null  object
#  7   rest_type     43499 non-null  object
#  8   cuisines      43499 non-null  object
#  9   cost          43499 non-null  float64
#  10  reviews_list  43499 non-null  object
#  11  menu_item     43499 non-null  object
#  12  type          43499 non-null  object
#  13  city          43499 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 5.0+ MB

# %%
zomato1_rename['rate'].unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
zomato2 = zomato1_rename.loc[zomato1_rename.rate !='NEW']

# %%
zomato3 = zomato2.loc[zomato2.rate !='-'].reset_index(drop=True)

# %%
remove_slash = lambda x: x.replace('/5', '') if type(x) == np.str else x

# %%
remove_slash
# Out:
# <function __main__.<lambda>(x)>

# %%
zomato3.rate = zomato3.rate.apply(remove_slash).str.strip().astype('float')
# Out:
# C:\Users\yoges\AppData\Local\Temp\ipykernel_25348\1612815623.py:1: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   remove_slash = lambda x: x.replace('/5', '') if type(x) == np.str else x

# %%
zomato3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41237 entries, 0 to 41236
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       41237 non-null  object
#  1   name          41237 non-null  object
#  2   online_order  41237 non-null  object
#  3   book_table    41237 non-null  object
#  4   rate          41237 non-null  float64
#  5   votes         41237 non-null  int64
#  6   location      41237 non-null  object
#  7   rest_type     41237 non-null  object
#  8   cuisines      41237 non-null  object
#  9   cost          41237 non-null  float64
#  10  reviews_list  41237 non-null  object
#  11  menu_item     41237 non-null  object
#  12  type          41237 non-null  object
#  13  city          41237 non-null  object
# dtypes: float64(2), int64(1), object(11)
# memory usage: 4.4+ MB

# %%
zomato3['rate']
# Out:
# 0        4.1
# 1        4.1
# 2        3.8
# 3        3.7
# 4        3.8
#         ...
# 41232    3.7
# 41233    2.5
# 41234    3.6
# 41235    4.3
# 41236    3.4
# Name: rate, Length: 41237, dtype: float64

# %%
zomato3.name = zomato3.name.apply(lambda x:x.title())

# %%
zomato3.online_order.replace(('Yes','No'),(True, False),inplace=True)

# %%
zomato3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato3.book_table.replace(('Yes','No'),(True, False),inplace=True)

# %%
zomato3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
zomato3['address'].factorize()[0]
# Out:
# array([   0,    1,    2, ..., 8725, 8786, 3444], dtype=int64)

# %%
zomato3_copy=zomato3.copy(deep=True)

# %%
def Encode(zomato):
    for column in zomato.columns[~zomato.columns.isin(['rate', 'cost', 'votes'])]:
        zomato[column] = zomato[column].factorize()[0]
    return zomato

# %%
zomato_en = Encode(zomato3_copy)

# %%
zomato_en
# Out:
#        address  name  online_order  book_table  rate  votes  location  \
# 0            0     0             0           0   4.1    775         0
# 1            1     1             0           1   4.1    787         0
# 2            2     2             0           1   3.8    918         0
# 3            3     3             1           1   3.7     88         0
# 4            4     4             1           1   3.8    166         1
# ...        ...   ...           ...         ...   ...    ...       ...
# 41232     3137  2699             1           1   3.7     34        25
# 41233     8791  1716             1           1   2.5     81        25
# 41234     8725  6532             1           1   3.6     27        25
# 41235     8786  6568             1           0   4.3    236        56
# 41236     3444  6569             1           1   3.4     13        56
#
#        rest_type  cuisines   cost  reviews_list  menu_item  type  city
# ...

# %%
zomato_en.corr()
# Out:
#                address      name  online_order  book_table      rate  \
# address       1.000000  0.682346      0.165707    0.021447 -0.036195
# name          0.682346  1.000000      0.231616   -0.033718 -0.046936
# online_order  0.165707  0.231616      1.000000   -0.054894 -0.069042
# book_table    0.021447 -0.033718     -0.054894    1.000000 -0.426027
# rate         -0.036195 -0.046936     -0.069042   -0.426027  1.000000
# votes        -0.010738 -0.043871      0.013278   -0.393270  0.435237
# location      0.614626  0.448705      0.048645   -0.032781  0.030363
# rest_type     0.030634  0.036212      0.136741   -0.226763  0.196933
# cuisines      0.238421  0.301793      0.049921   -0.225396  0.189624
# cost          0.003227 -0.084328     -0.180782    0.266651 -0.115346
# reviews_list  0.512074  0.339130      0.051440   -0.132809  0.159661
# menu_item     0.058929 -0.031798     -0.362114    0.040496  0.054942
# type          0.094137  0.116000      0.239236   -0.114302  0.034038
# ...

# %%
corr = zomato_en.corr(method='kendall')

# %%
corr
# Out:
#                address      name  online_order  book_table      rate  \
# address       1.000000  0.619183      0.135867    0.016287 -0.027134
# name          0.619183  1.000000      0.192243   -0.039834 -0.039526
# online_order  0.135867  0.192243      1.000000   -0.054894 -0.066107
# book_table    0.016287 -0.039834     -0.054894    1.000000 -0.375637
# rate         -0.027134 -0.039526     -0.066107   -0.375637  1.000000
# votes        -0.044685 -0.089772     -0.130885   -0.381838  0.534326
# location      0.398970  0.300501      0.056353   -0.053073  0.043804
# rest_type     0.015073  0.007592      0.107065   -0.054260  0.082933
# cuisines      0.120878  0.189661      0.018949   -0.192603  0.149959
# cost          0.000816 -0.067788     -0.152519    0.218509 -0.060617
# reviews_list  0.452800  0.288522      0.042956   -0.110904  0.125171
# menu_item    -0.021664 -0.078893     -0.399441    0.042958  0.052367
# type          0.076168  0.090088      0.233468   -0.104837  0.024298
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sns.heatmap(corr,annot=True,cmap='Set2')
# Out:
# <Axes: >

# %%
zomato3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 41232  136, SAP Labs India, KIADB Export Promotion In...
# 41233  139/C1, Next To GR Tech Park, Pattandur Agraha...
# 41234  Four Points by Sheraton Bengaluru, 43/3, White...
# 41235  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 41236  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name  online_order  \
# 0                                                  Jalsa          True
# 1                                         Spice Elephant          True
# ...

# %%
sns.countplot(zomato2,x='online_order')
# Out:
# <Axes: xlabel='online_order', ylabel='count'>

# %%
sns.countplot(zomato3,x='book_table')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Restaurants allowing table booking or not')
# Out:
# Text(0.5, 1.0, 'Restaurants allowing table booking or not')

# %%
plt.rcParams['figure.figsize'] = (13, 9)
Y = pd.crosstab(zomato3['rate'], zomato3['book_table'])
Y.div(Y.sum(1).astype(float), axis = 0).plot(kind = 'bar', stacked = True,color=['red','yellow'])
plt.title('table booking vs Normal rate', fontweight = 30, fontsize = 20)
plt.legend(loc="upper right")
plt.show()

# %%
sns.countplot(zomato3,x='city')
sns.countplot(zomato3,x='city').set_xticklabels(sns.countplot(zomato3,x='city').get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(13,13)
plt.title('Location wise count for restaurants')
# Out:
# Text(0.5, 1.0, 'Location wise count for restaurants')

# %%
loc_plt=pd.crosstab(zomato3['rate'],zomato3['city'])
loc_plt.plot(kind='bar',stacked=True);
plt.title('Locationwise Rating',fontsize=15,fontweight='bold')
plt.ylabel('Location',fontsize=10,fontweight='bold')
plt.xlabel('Rating',fontsize=10,fontweight='bold')
plt.xticks(fontsize=10,fontweight='bold')
plt.yticks(fontsize=10,fontweight='bold');
plt.legend();

# %%
sns.countplot(zomato3,x='type')
sns.countplot(zomato3,x='type').set_xticklabels(sns.countplot(zomato3,x='type').get_xticklabels(), rotation=90, ha="right")
fig = plt.gcf()
fig.set_size_inches(15,15)
plt.title('Type of Service')
# Out:
# Text(0.5, 1.0, 'Type of Service')

# %%
plt.figure(figsize=(15,7))
chains=zomato3['name'].value_counts()[:5]
sns.barplot(x=chains,y=chains.index,palette='Set1')
plt.title("Most famous restaurant chains in Bangaluru",size=20,pad=20)
plt.xlabel("Number of outlets",size=15)
# Out:
# Text(0.5, 0, 'Number of outlets')

# %%
from sklearn.svm import SVC

# %%
SVC
